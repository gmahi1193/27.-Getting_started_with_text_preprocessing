# %% [markdown]
# ## Text Data Preprocessing
#
# In any machine learning task, cleaning or preprocessing the data is as important as model building if not more. And when it comes to unstructured data like text, this process is even more important.
#
# Objective of this notebook is to understand the various text preprocessing steps with code examples.
#
# Some of the common text preprocessing / cleaning steps are:
#
# * Lower casing
# * Removal of Punctuations
# * Removal of Stopwords
# * Removal of Frequent words
# * Removal of Rare words
# * Stemming
# * Lemmatization
# * Removal of emojis
# * Removal of URLs
#
#
# So these are the different types of text preprocessing steps which we can do on text data. But we need not do all of these all the times. We need to carefully choose the preprocessing steps based on our use case since that also play an important role.
#
# For example, in sentiment analysis use case, we need not remove the emojis as it will convey some important information about the sentiment. Similarly we need to decide based on our use cases.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Read the data

# %%
data = pd.read_csv('../data/text.csv',lineterminator='\n')

# %%
pd.set_option('max_colwidth', 700)
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 What's that egg website people talk about
# 1                                                                                                                                         Why!🤷🏻‍♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq
# 2  @693975 We can assist you. We recommend updating to iOS 11.1.1 if you haven't had the chance to do so. You can also DM us with the following link for futher support. https://t.co/GDrqU22YpT
# 3                                                                                                     @331912 @115955 Thats better than having an unstable connection that drops every 5-20 mins
# 4                                                                                                                     @VirginAmerica is probably one of the best airlines I've ever experienced.

# %%
data.style.set_properties(subset=['text'], **{'width': '300px'})
# Out:
# <style type="text/css">
# #T_d361f_row0_col0, #T_d361f_row1_col0, #T_d361f_row2_col0, #T_d361f_row3_col0, #T_d361f_row4_col0, #T_d361f_row5_col0, #T_d361f_row6_col0, #T_d361f_row7_col0, #T_d361f_row8_col0, #T_d361f_row9_col0, #T_d361f_row10_col0, #T_d361f_row11_col0, #T_d361f_row12_col0, #T_d361f_row13_col0, #T_d361f_row14_col0, #T_d361f_row15_col0, #T_d361f_row16_col0, #T_d361f_row17_col0, #T_d361f_row18_col0, #T_d361f_row19_col0, #T_d361f_row20_col0, #T_d361f_row21_col0, #T_d361f_row22_col0, #T_d361f_row23_col0, #T_d361f_row24_col0, #T_d361f_row25_col0, #T_d361f_row26_col0, #T_d361f_row27_col0, #T_d361f_row28_col0, #T_d361f_row29_col0, #T_d361f_row30_col0, #T_d361f_row31_col0, #T_d361f_row32_col0, #T_d361f_row33_col0, #T_d361f_row34_col0, #T_d361f_row35_col0, #T_d361f_row36_col0, #T_d361f_row37_col0, #T_d361f_row38_col0, #T_d361f_row39_col0, #T_d361f_row40_col0, #T_d361f_row41_col0, #T_d361f_row42_col0, #T_d361f_row43_col0, #T_d361f_row44_col0, #T_d361f_row45_col0, #T_d361f_row46_col0, #T_d361f_row47_col0, #T_d361f_row48_col0, #T_d361f_row49_col0, #T_d361f_row50_col0, #T_d361f_row51_col0, #T_d361f_row52_col0, #T_d361f_row53_col0, #T_d361f_row54_col0, #T_d361f_row55_col0, #T_d361f_row56_col0, #T_d361f_row57_col0, #T_d361f_row58_col0, #T_d361f_row59_col0, #T_d361f_row60_col0, #T_d361f_row61_col0, #T_d361f_row62_col0, #T_d361f_row63_col0, #T_d361f_row64_col0, #T_d361f_row65_col0, #T_d361f_row66_col0, #T_d361f_row67_col0, #T_d361f_row68_col0, #T_d361f_row69_col0, #T_d361f_row70_col0, #T_d361f_row71_col0, #T_d361f_row72_col0, #T_d361f_row73_col0, #T_d361f_row74_col0, #T_d361f_row75_col0, #T_d361f_row76_col0, #T_d361f_row77_col0, #T_d361f_row78_col0, #T_d361f_row79_col0, #T_d361f_row80_col0, #T_d361f_row81_col0, #T_d361f_row82_col0, #T_d361f_row83_col0, #T_d361f_row84_col0, #T_d361f_row85_col0, #T_d361f_row86_col0, #T_d361f_row87_col0, #T_d361f_row88_col0, #T_d361f_row89_col0, #T_d361f_row90_col0, #T_d361f_row91_col0, #T_d361f_row92_col0, #T_d361f_row93_col0, #T_d361f_row94_col0, #T_d361f_row95_col0, #T_d361f_row96_col0, #T_d361f_row97_col0, #T_d361f_row98_col0, #T_d361f_row99_col0, #T_d361f_row100_col0, #T_d361f_row101_col0, #T_d361f_row102_col0, #T_d361f_row103_col0, #T_d361f_row104_col0, #T_d361f_row105_col0, #T_d361f_row106_col0, #T_d361f_row107_col0, #T_d361f_row108_col0, #T_d361f_row109_col0, #T_d361f_row110_col0, #T_d361f_row111_col0, #T_d361f_row112_col0, #T_d361f_row113_col0, #T_d361f_row114_col0, #T_d361f_row115_col0, #T_d361f_row116_col0, #T_d361f_row117_col0, #T_d361f_row118_col0, #T_d361f_row119_col0, #T_d361f_row120_col0, #T_d361f_row121_col0, #T_d361f_row122_col0, #T_d361f_row123_col0, #T_d361f_row124_col0, #T_d361f_row125_col0, #T_d361f_row126_col0, #T_d361f_row127_col0, #T_d361f_row128_col0, #T_d361f_row129_col0, #T_d361f_row130_col0, #T_d361f_row131_col0, #T_d361f_row132_col0, #T_d361f_row133_col0, #T_d361f_row134_col0, #T_d361f_row135_col0, #T_d361f_row136_col0, #T_d361f_row137_col0, #T_d361f_row138_col0, #T_d361f_row139_col0, #T_d361f_row140_col0, #T_d361f_row141_col0, #T_d361f_row142_col0, #T_d361f_row143_col0, #T_d361f_row144_col0, #T_d361f_row145_col0, #T_d361f_row146_col0, #T_d361f_row147_col0, #T_d361f_row148_col0, #T_d361f_row149_col0, #T_d361f_row150_col0, #T_d361f_row151_col0, #T_d361f_row152_col0, #T_d361f_row153_col0, #T_d361f_row154_col0, #T_d361f_row155_col0, #T_d361f_row156_col0, #T_d361f_row157_col0, #T_d361f_row158_col0, #T_d361f_row159_col0, #T_d361f_row160_col0, #T_d361f_row161_col0, #T_d361f_row162_col0, #T_d361f_row163_col0, #T_d361f_row164_col0, #T_d361f_row165_col0, #T_d361f_row166_col0, #T_d361f_row167_col0, #T_d361f_row168_col0, #T_d361f_row169_col0, #T_d361f_row170_col0, #T_d361f_row171_col0, #T_d361f_row172_col0, #T_d361f_row173_col0, #T_d361f_row174_col0, #T_d361f_row175_col0, #T_d361f_row176_col0, #T_d361f_row177_col0, #T_d361f_row178_col0, #T_d361f_row179_col0, #T_d361f_row180_col0, #T_d361f_row181_col0, #T_d361f_row182_col0, #T_d361f_row183_col0, #T_d361f_row184_col0, #T_d361f_row185_col0, #T_d361f_row186_co ...

# %%
sample_string = data['text'].values[1]

# %%
sample_string
# Out:
# 'Why!🤷🏻\u200d♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq'

# %% [markdown]
# ## Lower Casing
# Lower casing is a common text preprocessing technique. The idea is to convert the input text into same casing format so that 'text', 'Text' and 'TEXT' are treated the same way.

# %%
sample_string.lower()
# Out:
# 'why!🤷🏻\u200d♀️ #ios11 @applesupport https://t.co/bxrvfeixxq'

# %%
data['text'] = data['text'].map(lambda x : x.lower())

# %%
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 what's that egg website people talk about
# 1                                                                                                                                         why!🤷🏻‍♀️ #ios11 @applesupport https://t.co/bxrvfeixxq
# 2  @693975 we can assist you. we recommend updating to ios 11.1.1 if you haven't had the chance to do so. you can also dm us with the following link for futher support. https://t.co/gdrqu22ypt
# 3                                                                                                     @331912 @115955 thats better than having an unstable connection that drops every 5-20 mins
# 4                                                                                                                     @virginamerica is probably one of the best airlines i've ever experienced.

# %% [markdown]
# ## Removal of Punctuations
#
# One another common text preprocessing technique is to remove the punctuations from the text data. This is again a text standardization process that will help to treat 'hurray' and 'hurray!' in the same way.
#
# We also need to carefully choose the list of punctuations to exclude depending on the use case. For example, the string.punctuation in python contains the following punctuation symbols !"#$%&\'()*+,-./:;<=>?@[\\]^_{|}~`
#
# We can add or remove more punctuations as per our need.

# %%
puncts = string.punctuation
puncts
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
test = "he;y i', am , aweso,/m!e@ ]follow /me"

# %%
for p in list(puncts):
    test = test.replace(p,"")
print(test)
# Out:
# hey i am  awesome follow me

# %%
# re.sub("[^\d\w\s]","",test)

# %%
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    
    res = []
    for t in text.split():
        if t.lower().startswith('http'):
            res.append(t)
        else:
            res.append(t.translate(str.maketrans('', '', puncts)))
        
    return " ".join(res)

# %%
remove_punctuation(sample_string)
# Out:
# 'Why🤷🏻\u200d♀️ iOS11 AppleSupport https://t.co/BXrVfeIXxq'

# %%
data['text'] = data['text'].map(remove_punctuation)
data.head()
# Out:
#                                                                                                                                                                                      text
# 0                                                                                                                                         161252 whats that egg website people talk about
# 1                                                                                                                                     why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2  693975 we can assist you we recommend updating to ios 1111 if you havent had the chance to do so you can also dm us with the following link for futher support https://t.co/gdrqu22ypt
# 3                                                                                                 331912 115955 thats better than having an unstable connection that drops every 520 mins
# 4                                                                                                                 virginamerica is probably one of the best airlines ive ever experienced

# %% [markdown]
# ## Removal of stopwords
# Stopwords are commonly occuring words in a language like 'the', 'a' and so on. They can be removed from the text most of the times, as they don't provide valuable information for downstream analysis. In cases like Part of Speech tagging, we should not remove them as provide very valuable information about the POS.
#
# These stopword lists are already compiled for different languages and we can safely use them. For example, the stopword list for english language from the nltk package can be seen below.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gmahi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stw = set(stopwords.words("English"))
print(stw)
# Out:
# {'doing', 'between', 'mightn', 'its', 'd', 'on', 'be', 'down', 'now', "doesn't", 'they', 'from', 'but', 'don', 'than', 'has', 'his', "shan't", 'against', 'my', 'off', 't', 'her', "that'll", 'did', 'over', 'should', 'mustn', "needn't", 'each', "you're", 'other', 'hers', "it's", 'yourselves', 'when', 'ourselves', "mightn't", 'under', "wouldn't", 'again', 'up', 'both', 'some', 'what', 'all', 'until', 'just', 'with', 'below', 'in', 'we', 'whom', 'themselves', 'at', 'their', "you'd", 'm', 'are', 'myself', 'isn', 'a', 'very', 'and', 'shan', 'out', 'itself', "couldn't", 'those', 'after', 'the', 'he', 'into', 'were', 'here', 'i', 'for', 'then', 'theirs', 'this', 'why', "should've", 'ma', 'which', 'as', 'she', 'nor', 'any', 'few', 's', 'weren', 'how', 'do', 'yourself', 'before', 'yours', 'more', 'does', 'it', 'me', 'hadn', 'haven', "you've", 'hasn', "aren't", 'ours', 'there', 'shouldn', 'herself', 've', 'of', 'ain', "you'll", 'same', 'been', 'such', 'am', 'further', "hadn't", 'doesn', 'about', 'above', "won't", 'no', 'will', "weren't", 'won', 're', 'you', "don't", 'because', 'y', 'needn', 'too', 'that', 'your', 'himself', 'most', 'through', 'or', "wasn't", 'had', 'these', 'not', 'didn', "mustn't", 'to', 'couldn', 'during', 'is', 'only', 'wouldn', "isn't", 'where', "shouldn't", 'him', 'wasn', 'our', 'can', 'o', "she's", 'having', 'by', 'being', 'if', 'll', 'aren', 'so', 'while', 'an', 'them', "haven't", 'was', 'who', "hasn't", 'have', 'own', 'once', "didn't"}

# %%
def remove_stopwords(text):
    res = []
    for w in text.split():
        if w.lower() not in stw:
            res.append(w)
    return " ".join(res)

# %%
remove_stopwords(test)
# Out:
# 'hey awesome follow'

# %%
data['text'] = data['text'].map(remove_stopwords)

# %%
data.head()
# Out:
#                                                                                                                        text
# 0                                                                                      161252 whats egg website people talk
# 1                                                                       why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2  693975 assist recommend updating ios 1111 havent chance also dm us following link futher support https://t.co/gdrqu22ypt
# 3                                                       331912 115955 thats better unstable connection drops every 520 mins
# 4                                                             virginamerica probably one best airlines ive ever experienced

# %% [markdown]
# ## Removal of Frequent words
# In the previos preprocessing step, we removed the stopwords based on language information. But say, if we have a domain specific corpus, we might also have some frequent words which are of not so much importance to us.
#
# So this step is to remove the frequent words in the given corpus. If we use something like tfidf, this is automatically taken care of.
#
# Let us get the most common words adn then remove them in the next step

# %%
from collections import Counter
cnt = Counter()
for text in data["text"].values:
    for word in text.split():
        cnt[word] += 1
        
most_frequent = [c[0] for c in cnt.most_common(10)]
most_frequent
# Out:
# ['us', 'please', 'dm', 'help', 'hi', 'thanks', 'get', 'sorry', 'like', 'send']

# %%
def remove_frequent_words(text):
    res = []
    for w in text.split():
        if w.lower() not in most_frequent:
            res.append(w)
    return " ".join(res)

# %%
data['text'] = data['text'].map(remove_frequent_words)

# %%
data.head()
# Out:
#                                                                                                                  text
# 0                                                                                161252 whats egg website people talk
# 1                                                                 why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2  693975 assist recommend updating ios 1111 havent chance also following link futher support https://t.co/gdrqu22ypt
# 3                                                 331912 115955 thats better unstable connection drops every 520 mins
# 4                                                       virginamerica probably one best airlines ive ever experienced

# %% [markdown]
# ## Removal of Rare words
# This is very similar to previous preprocessing step but we will remove the rare words from the corpus.

# %%
cnt.most_common()[-11:-1]
# Out:
# [('319396', 1),
#  ('gravity', 1),
#  ('reunion', 1),
#  ('407091', 1),
#  ('implementing', 1),
#  ('bricked', 1),
#  ('170844', 1),
#  ('inr1400', 1),
#  ('puma', 1),
#  ('custom', 1)]

# %%
rare_words = set([w[0] for w in cnt.most_common() if w[1] == 1])

# %%
def remove_rare_words(text):
    res = []
    for w in text.split():
        if w.lower() not in rare_words or w.lower().startswith('http'):
            res.append(w)
    return " ".join(res)

# %%
data['text'] = data['text'].map(remove_rare_words)

# %%
data.head()
# Out:
#                                                                                                    text
# 0                                                                         whats egg website people talk
# 1                                                            ios11 applesupport https://t.co/bxrvfeixxq
# 2  assist recommend updating ios 1111 havent chance also following link support https://t.co/gdrqu22ypt
# 3                                                       115955 thats better connection drops every mins
# 4                                         virginamerica probably one best airlines ive ever experienced

# %% [markdown]
# ## Stemming
# Stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form (From Wikipedia)
#
# For example, if there are two words in the corpus walks and walking, then stemming will stem the suffix to make them walk. But say in another example, we have two words console and consoling, the stemmer will remove the suffix and make them consol which is not a proper english word.
#
# There are several type of stemming algorithms available and one of the famous one is porter stemmer which is widely used. We can use nltk package for the same.

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem_text(text):
    res = []
    for w in text.split():
        res.append(ps.stem(w))
    return " ".join(res)

# %%
data['text'] = data['text'].map(stem_text)

# %%
data.head()
# Out:
#                                                                                            text
# 0                                                                    what egg websit peopl talk
# 1                                                    ios11 applesupport https://t.co/bxrvfeixxq
# 2  assist recommend updat io 1111 havent chanc also follow link support https://t.co/gdrqu22ypt
# 3                                                     115955 that better connect drop everi min
# 4                                      virginamerica probabl one best airlin ive ever experienc

# %% [markdown]
# ## Lemmatization
# Lemmatization is similar to stemming in reducing inflected words to their word stem but differs in the way that it makes sure the root word (also called as lemma) belongs to the language.
#
# As a result, this one is generally slower than stemming process. So depending on the speed requirement, we can choose to use either stemming or lemmatization.
#
# Let us use the WordNetLemmatizer in nltk to lemmatize our sentences

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("dancing", pos='v')
# Out:
# 'dance'

# %% [markdown]
# ## Redo the lemmatization process with POS tag for our dataset.

# %%
# Identify the POS tag
# import nltk
# nltk.download('averaged_perceptron_tagger')

nltk.pos_tag("I am dancing to my heart".split())
# Out:
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('dancing', 'VBG'),
#  ('to', 'TO'),
#  ('my', 'PRP$'),
#  ('heart', 'NN')]

# %% [markdown]
# ## Removal of Emojis
#
# With more and more usage of social media platforms, there is an explosion in the usage of emojis in our day to day life as well. Probably we might need to remove these emojis for some of our textual analysis.
#
# Thanks to [this code](https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b), please find below a helper function to remove emojis from our text.

# %%
# Reference : https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

remove_emoji("game is on 🔥🔥")
# Out:
# 'game is on '

# %%
data['text'] = data['text'].map(remove_emoji)
data.head()
# Out:
#                                                                                            text
# 0                                                                    what egg websit peopl talk
# 1                                                    ios11 applesupport https://t.co/bxrvfeixxq
# 2  assist recommend updat io 1111 havent chanc also follow link support https://t.co/gdrqu22ypt
# 3                                                     115955 that better connect drop everi min
# 4                                      virginamerica probabl one best airlin ive ever experienc

# %% [markdown]
# ## Removal of URLs
#
# Next preprocessing step is to remove any URLs present in the data. For example, if we are doing a twitter analysis, then there is a good chance that the tweet will have some URL in it. Probably we might need to remove them for our further analysis.
#
# We can use the below code snippet to do that

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+|t\.co\S+')
    return url_pattern.sub(r'', text)

# %%
data['text'] = data['text'].map(remove_urls)

# %%
data.head()
# Out:
#                                                                     text
# 0                                             what egg websit peopl talk
# 1                                                    ios11 applesupport
# 2  assist recommend updat io 1111 havent chanc also follow link support
# 3                              115955 that better connect drop everi min
# 4               virginamerica probabl one best airlin ive ever experienc
